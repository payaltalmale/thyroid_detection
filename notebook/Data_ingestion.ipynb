# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd

# %%
#"Reading the dataset"
df = pd.read_csv("thyroid.csv")

# %%
df.head()
# Out:
#    age sex thyroxine query on thyroxine antithyroid medication sick pregnant  \
# 0   29   F         f                  f                      f    f        f
# 1   29   F         f                  f                      f    f        f
# 2   41   F         f                  f                      f    f        f
# 3   36   F         f                  f                      f    f        f
# 4   32   F         f                  f                      f    f        f
#
#   thyroid surgery I131 treatment query hypothyroid  ... TT4 measured  TT4  \
# 0               f              f                 t  ...            f    ?
# 1               f              f                 f  ...            t  128
# 2               f              f                 f  ...            f    ?
# 3               f              f                 f  ...            f    ?
# 4               f              f                 f  ...            f    ?
#
#   T4U measured T4U FTI measured FTI TBG measured TBG referral source  \
# 0            f   ?            f   ?            f   ?           other
# 1            f   ?            f   ?            f   ?           other
# 2            f   ?            f   ?            t  11           other
# 3            f   ?            f   ?            t  26           other
# 4            f   ?            f   ?            t  36           other
#
#           class
# 0  -[840801013]
# 1  -[840801014]
# 2  -[840801042]
# 3  -[840803046]
# 4  S[840803047]
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (9172, 30)

# %%
#Saving the first character in a new column. Because thats what matter for this problem statement.
df["outcome"] = df["class"].str[0]
df.drop(columns="class", inplace=True)

# %%
#Replacing all possible disease outcomes into one category - "yes".
label_list = ['S', 'F', 'A', 'R', 'I', 'M', 'N', 'G', 'K', 'L', 'Q', 'J',
       'C', 'O', 'H', 'D', 'P', 'B', 'E']
df['outcome'].replace(to_replace=label_list, value="yes", inplace=True)

# %%
df['outcome'].replace({"-": 0, "yes": 1}, inplace=True)

# %%
#saving the processed data 
df.to_csv("data_processed.csv", index=False)
